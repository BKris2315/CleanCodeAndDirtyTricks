# %%
import wordcloud
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # CleanCodeAndDirtyTricks 🚀
# ## Session 01: 101 into Clean Coding and (basic) Program Structure
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 15%;">
# <img src="imgs/logo_rot.png" alt="Drawing" style="width: 60px;"/>
# </div>
#
# <div style="width: 80%;">
# <img src="imgs/0_q3-4kypImPD0VDPg.webp" alt="Drawing" style="height: 325px;"/>
# </div>
#
# </div>
#
# @#DKOP#TTK#WJSZ#PHYSICS#ComputerScience

# %% [markdown]
# # 👋 About Me: Kristóf Benedek
# _Physicist & Computational Scientis_
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# ## 🌍 Background
#
# - Passionate about **mathematical modeling of nature**
# - Strong interest in connecting **numbers with real-world phenomena**
# - Experienced in:
#   - **Statistical physics**
#   - **Network science & synchronization**
#   - **Computational physics**
#   - **AI applications & Computer Vision**
#
# </div>
#
# <div style="width: 48%;">
#
# ## 🌐 Based In
#
# **Budapest, Hungary** 🇭🇺
#
# **BME and HUN-REN MFA EK, KRL**
#
# ## 📬 Contact
#
# - 📧 kristof.benedek@edu.bme.hu
# - 🐙 [GitHub](https://github.com/bkris2315)
# - 💼 [LinkedIn](https://www.linkedin.com/in/kristof-benedek/)
# </div>
# </div>
#
# ### > _“Code is how I translate complexity into clarity.”_

# %% [markdown]
# # 0. About the course
# ## A 4-Session Interactive Seminar Series
#
#
# ## 🚀 What’s This About?
#
# Welcome to a practical and engaging seminar series on writing better code, building smarter workflows, and leveraging modern tools like AI and GitHub to level up your software development game.

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# ## 🧵 Topics We'll Explore
# 1. **🧼 Clean Code**
#    - Writing readable, maintainable code
#    - Documentation, naming, class/function design, typing
#
# 2. **⚙️ Python Code Optimization**
#    - Vectorization, parallelization, JIT, GPU use
#    - Object-oriented structure & debugging tips
#
#
# </div>
#
# <div style="width: 48%;">
#
# 3. **🤖 AI in Development**
#    - ChatGPT & GitHub Copilot
#    - Prompting, productivity, hallucinations, confidentiality
#
# 4. **🌐 GitHub & Project Management**
#    - Repo structure, PR workflow, branching, task management
#    - Beautiful READMEs, deployment basics
# </div>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# ## 🧠 Bonus (If Time Allows)
#
# - Symbolic math with Python
# - AI insights: transformers, contrastive learning, distillation, object detection
#
#
# ## 📅 Logistics
#
# - **Sessions:** 4 total (flexible ±1)
# - **When:** Fridays, 16:00 CET, (~90 mins each) (mind the official holidays due to Easter!)
# - **Format:** In-person, online, hybrid
# - **Style:** Interactive talks, code snippets, slides = minimal + focused
# - **Resources:** All materials hosted on a GitHub repo
# </div>
#
# <div style="width: 48%;">
#
# ## 🧩 Why Join?
#
# - Learn best practices for real-world development
# - Sharpen both your coding and collaboration skills
# - Get hands-on with tools that modern devs actually use
# </div>
# </div>
#
# ### > _Come write code that doesn’t just work — but works beautifully._

# %% [markdown]
# # I. Introduction
# <img src="imgs/clean_code.png" alt="Drawing"/>

# %% [markdown]
# # Why do we care?
#
# - Writing clean code is a timeless, crucial skill in software development.
# - Regardless of tech trends, **code remains the medium** through which we solve problems.
#
# ## What Prevents Clean Code?
# **Number one reason:**
# ### > “I’ll clean it up later.”
# > **Pro Tip:** “Later” never comes.

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
# <div style="width: 48%;">
#
# - Works... *for now*.
# - Causes:
#   - Tight deadlines
#   - Inexperience
#   - Sloppy habits
# - Results:
#   - Bugs 🐛
#   - Slower development 🐢
#   - Higher long-term costs 💸
# </div>
#
# <div style="width: 48%;">
#
# ## 💰 The Total Cost of Owning a Mess
#
# - Messy code = long-term pain
# - Every messy line today steals time tomorrow
# - Clean code = investment in **productivity**
#
# ## ⛺ The Boy Scout Rule
#
# > _“Leave the campground cleaner than you found it.”_
#
# - Make small improvements constantly
# - Clean code is not a one-time event — it’s a habit
#
# </div>
# </div>

# %% [markdown]
# # Clean code saves **time, bugs, and sanity** long-term

# %% [markdown]
# ## 🧼 What Is Clean Code?
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
#
# - Easy to read, maintain, extend
# - Key principles:
#   - Single Responsibility
#   - Minimize dependencies
#   - Avoid duplication
#
#
# </div>
#
# <div style="width: 48%;">
#
# - Habits:
#   - Meaningful names
#   - Small functions
#   - Tests!
#
# </div>
#
# </div>

# %%
# Keywords related to clean coding with some weighting for visual variety
keywords = {
    "Testable": 3,
    "Tested": 2,
    "Elegant": 3,
    "Efficient": 4,
    "Expressive": 3,
    "Expected": 2,
    "Readable": 5,
    "Minimal Dependencies": 2,
    "Maintainable": 5,
    "Self Documenting": 3,
    "Simple": 4,
    "Robust": 2,
    "Modular": 3,
    "Reusable": 2,
    "Scalable": 2,
    "Clear": 3,
    "DRY (Don't Repeat Yourself)": 2,
    "YAGNI (You Aren't Gonna Need It)": 1,
    "KISS (Keep It Simple, Stupid)": 2,
    "SOLID Principles": 3,
    "Refactorable": 2
}

# Generate the word cloud
wordcloud = wordcloud.WordCloud(width=1920, height=1080,
                      colormap='inferno',
                       background_color='maroon').generate_from_frequencies(keywords)

# Display the word cloud
plt.figure(figsize=(12, 6), dpi=150)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## 🤯 What Clean Code Is NOT
#
# - Complex, over-engineered code
# - Duplicated or misleading code
# - Code that hides logic or purpose

# %% [markdown]
# # II. Meaningful Names
# <img src="imgs/funny-meme-about-forgetting-peoples-names-just-after-meeting-them.jpeg" alt="Drawing" style="height: 500px;"/>

# %% [markdown]
# ## 🧠 Why Names Matter
#
# - Naming is **one of the hardest problems** in programming.
# - Poor naming leads to **confusion, bugs, and harder maintenance**.
# - Your code is read more often than it’s written — name things like you care!
#
# If your naming is bad, you need comments. **A well-written code does not need any additional comment** apart from a docstring. More on comments in Ch. IV.

# %% [markdown]
# ## 🎯 Use Intention-Revealing Names
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
# ```c
# int d;
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```C
# int daysUntilExpiration;
# ```
# </div>
# </div>
#
# ### > Names should clearly describe what the variable does or represents.

# %% [markdown]
# ## 🚫 Avoid Disinformation
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
# ```c
# int temp = 20; // temp = temporary? temperature?
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```C
# int temperatureCelsius = 20;
# ```
# </div>
# </div>
#
#
# ### > Misleading names are worse than vague ones — don’t lie to the reader.

# %% [markdown]
# ## 🧍 Make Meaningful Distinctions
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
#
# ```c
# int data;
# int data1;
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```C
# int userData;
# int adminData;
# ```
# </div>
# </div>
#
# ### > Names must differentiate with purpose, not just slight variations.

# %% [markdown]
# ## 📣 Use Pronounceable Names
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
#
# ```c
# int genymdhmsepch;
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```C
# int generationTimestampEpoch;
# ```
# </div>
# </div>
#
# ### > If you can't say the variable name, you probably won't discuss it either.

# %% [markdown]
# ## 🔍 Use Searchable Names
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
#
# ```c
# int x;
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```C
# int maxUserCount;
#
# ```
# </div>
#
# </div>
#
# ## > Short names make searching and understanding harder. Use descriptive terms.

# %% [markdown]
# ## 🧠 Avoid Mental Mapping
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
#
# ```c
# int r; // radius? ratio? result?
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```c
# int gardenRadius;
# ```
# </div>
# </div>
#
# ### > Don’t make others decode your intentions — be explicit.

# %% [markdown]
# ## 🧾 Class & Method Names
# #### **Classes**: Use nouns or noun phrases
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
# ```java
# class Data;
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```java
# class Customer;
# ```
# </div>
# </div>
#
#
#
#
# #### **Methods**: Use verbs or verb phrases
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
# ```java
# void data();
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```java
# void saveCustomerData();
# ```
# </div>
#
# </div>
#
# ### > Class: what it is. Method: what it does.

# %% [markdown]
# ## ♻️ Pick One Word per Concept
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
# ```java
# fetchData();
# getUserData();
# retrieveAdminData();
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```java
# fetchData();
# fetchUserData();
# fetchAdminData();
# ```
# </div>
#
# </div>
#
# ### > Be consistent with terminology across the project.

# %% [markdown]
# ## 🏷 Use Domain-Specific Names
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
# ```c
# int count;
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```c
# int overdueBookCount;
# ```
# </div>
# </div>
#
# ### > Use the language of your domain to improve relevance and clarity.

# %% [markdown]
# ## 📦 Add Meaningful Context
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **Bad:**
# ```c
# int value;
# ```
# </div>
#
# <div style="width: 48%;">
#
# **Good:**
# ```c
# int orderValue;
# ```
# </div>
# </div>
#
# ### > Add just enough context to make the name self-explanatory.

# %% [markdown]
# ## 🧾 Mainstream Naming Conventions
#
# | Case Style        | Used For                           | Example                    | Common In                   |
# |-------------------|-------------------------------------|----------------------------|-----------------------------|
# | **camelCase**     | Variables, functions                | `totalCount`, `saveUser()` | JavaScript, Java, C#, Swift |
# | **PascalCase**    | Classes, types, constructors        | `CustomerAccount`, `AppView` | C#, Java, TypeScript       |
# | **snake_case**    | Variables, functions (esp. in Python) | `total_count`, `save_user()` | Python, Ruby, C, C++        |
# | **SCREAMING_SNAKE_CASE** | Constants                     | `MAX_CONNECTIONS`, `DEFAULT_TIMEOUT` | C, Python, Go, many more   |
# | **kebab-case**    | Filenames, URLs, CLI options        | `clean-code.md`, `--user-name` | HTML/CSS files, URLs, CLI  |
# | **dot.case**      | Config files, package names         | `clean.code.config`        | JSON, npm, file systems     |
#
#
# ### ✅ General Naming Best Practices
#
# - **Be consistent**: Stick to one convention per project.
# - **Reflect meaning**: Names should describe purpose, not implementation.
# - **Avoid abbreviations** unless widely accepted (e.g. `id`, `url`).
# - **Pluralize collections**: `users` for a list, `user` for a single object.
# - **Prefix booleans** with verbs: `isVisible`, `hasAccess`, `canEdit`.

# %% [markdown]
# ## Summary
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# **✅ Do:**
# - Reveal intent
# - Be specific
# - Use consistent terms
# - Favor domain terminology
#
# **🚫 Avoid:**
# - Vague, short names
# - Misleading labels
# - Arbitrary distinctions
# - Jargon or abbreviations
#
#
# </div>
#
# <div style="width: 48%;">
#
# ### > “Naming is not just about identification — it’s about communication.”
#
# Well-named code explains itself and reduces the need for comments. It’s one of the most powerful tools in writing clean, professional software.
#
# </div>
#
# </div>

# %% [markdown]
# # III. Functions
# _A guide to writing clean, small, and meaningful functions_
#
# <img src="imgs/programmerhumor-io-python-memes-backend-memes-6171778fb27c5f2.jpg" alt="Drawing" style="height: 500px;"/>

# %% [markdown]
# ## 📏 Keep It Small
#
# > “Functions should be short. Really short."
#
# **Why?**
# - Easier to read and understand
# - Easier to reuse and test
# - Tells a story, one step at a time

# %% [markdown]
# ### Example
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
#
# ### ⛔️ **Bad**
# ```python
# def process_user(user_data):
#     # many unrelated operations here
#     ...
# ```
# </div>
#
# <div style="width: 48%;">
#
# ## ✅ **Good**
# ```python
# def validate_user(user_data): ...
# def store_user(user_data): ...
# def notify_user(user_data): ...
# ```
# </div>
# </div>
#
# ---
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# ```python
# def elapse(year):
#     days = 365
#     if year % 4 == 0 or (year % 100 == 0 and year % 400 == 0):
#         days += 1
#     for day in range(1, days + 1):
#         print(f"Day {day} of {year}")
# ```
# </div>
#
# <div style="width: 48%;">
#
# ```python
# def is_leap(year): ...
# def elapse(year):
#     days = 366 if is_leap(year) else 365
#     ...
# ```
# </div>
# </div>

# %% [markdown]
# ## 🎯 Do One Thing
#
# A function should do **only one thing** — and do it well. Also called the **DRY Principle** (Don't Repeat Yourself).
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# ### ⛔️ Bad (Python):
# ```python
# def create_user(name, email, password):
#     if not name:
#         raise ValueError("Invalid name")
#     store_user_in_db(name, email, hash_password(password))
# ```
# </div>
#
# <div style="width: 48%;">
#
# ### ✅ Good (Python):
# ```python
# def validate_name(name): ...
# def hash_password(password): ...
# def store_user(name, email, hashed_pw): ...
# ```
# </div>
# </div>

# %% [markdown]
# ## 🧠 Use Descriptive Names
#
# **Good names tell the reader what the function does.**
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# ### ⛔️ Bad (C):
# ```c
# int doIt(int a, int b) {
#     return a + b;
# }
# ```
# </div>
#
# <div style="width: 48%;">
#
# ### ✅ Good (C):
#
# ```c
# int addTwoNumbers(int firstNumber, int secondNumber) {
#     return firstNumber + secondNumber;
# }
# ```
# </div>
# </div>

# %% [markdown]
# ## 🧮 Minimize Function Arguments
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# - Ideal: **0 (niladic)**
# - Good: **1 (monadic)**
# - Acceptable: **2 (dyadic)**
# - Avoid: **3+ (triadic/polyadic)** unless necessary
# </div>
#
# <div style="width: 48%;">
#
# ### 🧵 Bundle related args:
# ```python
# # Instead of:
# def draw_box(x, y, width, height): ...
#
# # Prefer:
# def draw_box(rect):  # where rect is a namedtuple or object
# ```
# </div>
# </div>

# %% [markdown]
# ## ❓ Command–Query Separation
#
# > Functions should either **do something** or **answer something**, not both.
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# ### ⛔️ Bad:
# ```python
# def set_username(username):  # returns success?
#     ...
# ```
# </div>
#
# <div style="width: 48%;">
#
# ### ✅ Good:
# ```python
# def username_exists(username): ...
# def update_username(username): ...
# ```
# </div>
# </div>

# %% [markdown]
# ## 🚨 Prefer Exceptions Over Error Codes
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# ### ⛔️ Bad (C-style):
#
# ```c
# int openFile(char* path) {
#     if (path == NULL) return -1;
#     // ...
#     return 0;
# }
# ```
# </div>
#
# <div style="width: 48%;">
#
# ### ✅ Good (Python):
# ```python
# def open_file(path):
#     if not path:
#         raise ValueError("Invalid path")
# ```
# </div>
# </div>

# %% [markdown]
# ## 🔁 Don't Repeat Yourself (DRY), again
#
# Avoid copy-pasting logic — abstract instead.
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# ### ⛔️ Bad (Python):
# ```python
# def sum_two(a, b): return a + b
# def sum_three(a, b, c): return a + b + c
# ```
# </div>
#
# <div style="width: 48%;">
#
# ### ✅ Good:
# ```python
# def sum_all(*args):
#     return sum(args)
# ```
# </div>
# </div>

# %% [markdown]
# ## ✅ Recap: Function Best Practices
#
# | Principle | Description |
# |----------|-------------|
# | **Small** | Short and focused |
# | **Do One Thing** | No multitasking |
# | **Descriptive Names** | Self-documenting code |
# | **Few Arguments** | Prefer 0–2 args |
# | **Command ≠ Query** | Clear responsibility |
# | **Use Exceptions** | Don’t return error codes |
# | **DRY** | Reuse logic, avoid duplication |
#
#
# ### > _“Clean functions are like clean tools: precise, sharp, and made for a single task.”_
#
# Let your functions tell a story — clearly, one well-named step at a time.

# %% [markdown]
# # IV. Comments Are Bad
# _When (not) to comment your code_
#
# <img src="imgs/stop-sign-writing-comments-stop-this-is-stop-sign.jpeg" alt="Drawing" style="height: 500px;"/>

# %% [markdown]
# ## 🧼 The Philosophy
#
# > _“Don’t comment bad code — rewrite it.”_
# — Robert C. Martin
#
# - Comments are a **necessary evil**, not a best practice.
# - Code should be **self-explanatory** — comments are a fallback.
# - Most comments decay into **misleading noise** over time.

# %% [markdown]
# ## ⚠️ Why Comments Can Be Bad
#
# - **Get outdated** as code changes
# - Can **lie** or mislead
# - Are often used to explain **unclear code**
# - Create **maintenance burden**

# %% [markdown]
# ## 🧠 Code Should Speak For Itself
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
# Instead of this:
# ```python
# # increase balance by 10%
# balance = balance + balance * 0.1
# ```
# </div>
#
# <div style="width: 48%;">
#
# Do this
# ```python
# def apply_interest(balance, rate=0.1):
#     return balance * (1 + rate)
# ```
# </div>
# </div>

# %% [markdown]
# ## ✅ When Comments Are Useful
#
# ### 📜 Legal Comments
# Licensing and copyright info.
#
# ### 🧾 Informative Comments
# Explaining non-obvious things (e.g., regexes, hardware constraints).
#
# ### 🧠 Intent Explanation
# Why something is done a certain way, not *what* is being done.
#
# ```python
# # Priority queue used for Dijkstra's algorithm
# queue = PriorityQueue()
# ```

# %% [markdown]
# ### 🔍 Clarification
# For unavoidable obscurities:
# ```python
# # API returns 0 for success, 1 for failure 🤷
# if api_call() == 0: ...
# ```
#
# ### ⚠️ Warning of Consequences
# ```python
# # ⚠️ This test takes ~5 min to run!
# def test_large_dataset(): ...
# ```

# %% [markdown]
# ### 🛠 TODOs
# Track incomplete tasks (but remove when resolved).
#
# ```python
# # TODO: Add support for edge cases
# ```
#
# ### 📣 Amplification
# Highlighting subtle but crucial detail:
# ```python
# # Trim to avoid trailing whitespace bugs
# cleaned_name = name.strip()
# ```
#
# ### 📚 Javadocs / Public API Docs
# Needed for external consumers, but must be maintained.

# %% [markdown]
# ## 🚫 Bad Comment Patterns
#
# | Type               | Problem                                |
# |--------------------|-----------------------------------------|
# | **Mumbling**       | Vague, unclear wording                  |
# | **Redundant**      | Repeats what the code already shows     |
# | **Misleading**     | No longer accurate                      |
# | **Mandated**       | Required but meaningless docs           |
# | **Journal Comments** | Version history — use Git instead    |
# | **Noise**          | Adds clutter, not clarity               |

# %% [markdown]
# ## ❌ Examples of Bad Comments
#
# ```python
# # increment i by 1
# i += 1  # ← no need for that comment
# ```
#
# ```c
# // Default constructor
# MyClass::MyClass() {}
# ```
#
# ```java
# // Changed on Jan 2023
# // Added null check
# ```
# > Use version control (Git!) instead.

# %% [markdown]
# ## 🧼 Comment TL;DR
#
# | 💡 Use Comments For         | 🚫 Avoid Comments That      |
# |-----------------------------|-----------------------------|
# | Legal / license info        | State the obvious           |
# | Intent or rationale         | Get out-of-sync easily      |
# | Real warnings / TODOs       | Replace poor naming         |
# | Public API documentation    | Could be refactored instead |
#
# ### > _“The best comment is the one you didn’t need to write because your code was clear enough.”_
#
# # **Refactor > explain.**

# %% [markdown]
# # And try to avoid this... seriously
#
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
# <img src="imgs/iuy9fxt300811.webp" alt="Meme 1" style="width: 100%;">
# </div>
#
# <div style="width: 48%;">
# <img src="imgs/unnamed.png" alt="Meme 2" style="width: 100%;">
# </div>
#
# </div>

# %% [markdown]
# # V. Venvs and docstrings
#
# <img src="imgs/documentation.png" alt="Meme 1" style="width: 50%;">

# %% [markdown]
# # 📄 Writing Good Docstrings (Google Style)
#
# > _“Comments explain **why**, docstrings explain **how to use**.”_
#
# ## 🧠 Why Use Docstrings?
#
# - Clarify usage of your functions/classes/modules
# - Help others (and future you) understand API contracts
# - Power tools like `help()`, IDEs, and doc generators

# %% [markdown]
# ## ✅ Google Style Format
#
# ```python
# def get_user(id: int, include_inactive: bool = False) -> dict:
#     """
#     Fetch a user by ID.
#
#     Args:
#         id (int): Unique user ID.
#         include_inactive (bool): Include inactive users. Default is False.
#
#     Returns:
#         dict: User data dictionary.
#
#     Raises:
#         ValueError: If ID is not found or invalid.
#     """
# ```
#
# ### ✨ Tips for Great Docstrings
#
# - First line = **short summary** (ends with period)
# - Use **imperative tone** (“Return...” not “Returns…”)
# - Include `Args`, `Returns`, `Raises`, and optional `Examples`
# - Document non-obvious behavior, defaults, edge cases

# %% [markdown]
# # 🧪 Virtual Environments in Python
#
# > _“A virtual environment is like a sandbox for your Python project.”_
#
# ## 🧩 Why Use Virtual Environments?
#
# - Isolate project dependencies (no system-wide mess)
# - Avoid version conflicts between projects
# - Reproducible environments for collaboration or deployment

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
#
# ## 🛠️ Creating One
#
# ```bash
# # Create
# python -m venv venv
#
# # Activate (Linux/macOS)
# source venv/bin/activate
#
# # Activate (Windows)
# venv\Scripts\activate
# ```
# </div>
#
# <div style="width: 48%;">
#
# ## 🧹 Best Practices
#
# - Name it `.venv` or `venv`, and **add to `.gitignore`**
# - Use `requirements.txt` or `pip freeze > requirements.txt`
# - Deactivate with:
# ```bash
# deactivate
# ```
# </div>
# </div>

# %% [markdown]
# ## 📦 With pip
#
# ```bash
# # Install packages locally to your env
# pip install numpy
#
# # Freeze for others
# pip freeze > requirements.txt
#
# # Reinstall for new devs
# pip install -r requirements.txt
# ```
#
# ### > _“If your project has a `venv` and a `README`, you're halfway to being professional.”_

# %% [markdown]
# # References
#
# 1. [Clean Code Notes](https://medium.com/@akineralkan/list/clean-code-notes-bb47e308d51e) by Akiner Alkan
# 2. Robert C. Martin: [Clean Code](https://www.amazon.com/Clean-Code-Handbook-Software-Craftsmanship/dp/0132350882)
# 3. [Clean Code in Python](https://ep2016.europython.eu/media/conference/slides/clean-code-in-python.pdf) by Mariano Anaya from EuroPython

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
#
# <div style="width: 48%;">
#
#
# </div>
#
# <div style="width: 48%;">
#
#
# </div>
# </div>
